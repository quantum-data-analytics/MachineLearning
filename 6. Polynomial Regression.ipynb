# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# Polynomial regression is regression where the model fits a polyniomial curve to your data. i.e. non-linear relationship

# %% [markdown]
# ![image.png](attachment:c5cf41a3-5027-41b2-9976-7dcfe1298f09.png)

# %% [markdown]
# ### Libraries used numpy matplotlib and scikit-learn

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Generate some data
np.random.seed(42)
X = (5*np.random.rand(80,1)) # Random Input Variables
y = X**3 + 2*X+np.random.normal(0, 0.5, size = (80,1)) # Polynomial relationship

# %%
# Visualize data 
plt.scatter(X,y, color = 'blue', label = 'Data')
plt.title("Sample Data")
plt.xlabel("Feature (X)")
plt.ylabel("Feature (y)")
plt.show()

# %%
# Transform data into polynomial feature
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

# %%
X_poly
# Out:
# array([[1.00000000e+00, 1.87270059e+00, 3.50700752e+00, 6.56757506e+00],
#        [1.00000000e+00, 4.75357153e+00, 2.25964423e+01, 1.07413805e+02],
#        [1.00000000e+00, 3.65996971e+00, 1.33953783e+01, 4.90266787e+01],
#        [1.00000000e+00, 2.99329242e+00, 8.95979952e+00, 2.68193000e+01],
#        [1.00000000e+00, 7.80093202e-01, 6.08545404e-01, 4.74722133e-01],
#        [1.00000000e+00, 7.79972602e-01, 6.08357259e-01, 4.74501994e-01],
#        [1.00000000e+00, 2.90418061e-01, 8.43426501e-02, 2.44946289e-02],
#        [1.00000000e+00, 4.33088073e+00, 1.87565279e+01, 8.12322852e+01],
#        [1.00000000e+00, 3.00557506e+00, 9.03348143e+00, 2.71508065e+01],
#        [1.00000000e+00, 3.54036289e+00, 1.25341694e+01, 4.43755081e+01],
#        [1.00000000e+00, 1.02922471e-01, 1.05930351e-02, 1.09026136e-03],
#        [1.00000000e+00, 4.84954926e+00, 2.35181280e+01, 1.14052320e+02],
#        [1.00000000e+00, 4.16221320e+00, 1.73240188e+01, 7.21062596e+01],
# ...

# %%
# fit the linear refression model to the transformed data
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# plotting the linear regression curve

X_grid = np.arange(min(X), max(X), 0.1) # Smooth curve for plotting
X_grid = X_grid.reshape(len(X_grid),1)
y_grid = model.predict(poly.transform(X_grid))

plt.scatter(X, y, color= 'blue', label = 'Data')
plt.plot(X_grid, y_grid, color = 'red', label = 'Polynomial Regression Line')
plt.title("Polynomial Regression Model")
plt.xlabel("Feature (X)")
plt.ylabel("Target (y)")
plt.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13716\2684506008.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1) # Smooth curve for plotting

# %%
# Calculate the MSE

y_pred = model.predict(X_poly)
mse = mean_squared_error(y, y_pred)
mse
# Out:
# np.float64(0.2235489942085775)

# %%
# import warnings
# warnings.filterwarnings("ignore")
