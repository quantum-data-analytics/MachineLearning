# %% [markdown]
# ## Support Vector Machine

# %% [markdown]
# What is SVM?
#
# ![image.png](attachment:cf580eef-7e8a-48e8-85a3-f8f86b3e1c5d.png)

# %% [markdown]
# # SVM Can handle different types of data
# 1. Linearly Separable Data
# 2. Linearly Inseparable Data
# 3. Nonlinear Data

# %% [markdown]
# M= ∥w∥/2
# ​M = Margin
# w is vector to the hyperplane

# %%
# Importing Libraries 

import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC

# %%
# Iris dataset

data = datasets.load_iris()
X = data.data[:,:2] 
y = data.target

# %%
model = SVC(kernel='linear')
model.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
# Visualize the decision boundry

h = 0.2 # step size
x_min, x_max = X[:, 0].min() -1, X[:, 0].max()+1
y_min, y_max = X[:, 0].min() -1, X[:, 0].max()+1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max,h))

Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Plotting the result 
plt.contourf(xx, yy, Z, alpha = 0.8)
plt.scatter(X[:, 0], X[:,1], c= y, edgecolors='k', marker = 'o', s=100, cmap = plt.cm.coolwarm)
plt.title("SVM Decision Boundary with Iris Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
print("4" + "4")
# Out:
# 44
